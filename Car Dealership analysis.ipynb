# %%
# Importing Libraries.
import numpy as np
import pandas as pd

# %%
# Reading data
Listings = pd.read_csv('listings.csv')
Vehicles = pd.read_csv('vehicles.csv')
Locations = pd.read_csv('locations.csv')

# %%
Listings
# Out:
#               id  price                VIN  \
# 0     7301603102  17995  1G6AG5RX3D0179091
# 1     7301683174   9995  1FAHP2E81FG150990
# 2     7301685395  24995  1N6BF0LYXHN802740
# 3     7301698635  17000        H255B003251
# 4     7301699921   6795  1FTPX14V66NB58277
# ...          ...    ...                ...
# 5177  7317070815  22995  WDAPF4CC7C9507524
# 5178  7317074981  14900  JF2SJADC4FG514905
# 5179  7317080335  14000  JTDKN3DU5F0443875
# 5180  7317096069  11995  1D7RV1GT0BS590812
# 5181  7317096748  34000  2GCVKRECXJ1109515
#
#                                             description  \
# 0     Super Sharp, Loaded, Low Mileage 2 Owner/No Ac...
# 1     Immaculate SEL. Runs and drives like new. It i...
# 2     2017 Nissan NV Cargo 2500 HD SV V6 High Roof -...
# 3     Model 3100 second series 1/2 ton short bed.  R...
# 4     You're looking at a sharp tan 2006 Ford F-150 ...
# ...                                                 ...
# ...

# %%
Listings = Listings[['id', 'price', 'VIN']]

# %%
Listings
# Out:
#               id  price                VIN
# 0     7301603102  17995  1G6AG5RX3D0179091
# 1     7301683174   9995  1FAHP2E81FG150990
# 2     7301685395  24995  1N6BF0LYXHN802740
# 3     7301698635  17000        H255B003251
# 4     7301699921   6795  1FTPX14V66NB58277
# ...          ...    ...                ...
# 5177  7317070815  22995  WDAPF4CC7C9507524
# 5178  7317074981  14900  JF2SJADC4FG514905
# 5179  7317080335  14000  JTDKN3DU5F0443875
# 5180  7317096069  11995  1D7RV1GT0BS590812
# 5181  7317096748  34000  2GCVKRECXJ1109515
#
# [5182 rows x 3 columns]

# %%
Vehicles
# Out:
#                     VIN  year   manufacturer           model  condition  \
# 0     1G6AG5RX3D0179091  2013       cadillac         ats awd  excellent
# 1     1FAHP2E81FG150990  2015           ford      taurus sel  excellent
# 2     1N6BF0LYXHN802740  2017         nissan        nv cargo       good
# 3           H255B003251  1955      chevrolet          pickup       good
# 4     1FTPX14V66NB58277  2006           ford       f-150 xlt       good
# ...                 ...   ...            ...             ...        ...
# 5173  WDAPF4CC7C9507524  2012  mercedes-benz        sprinter  excellent
# 5174  JF2SJADC4FG514905  2015         subaru        forester  excellent
# 5175  JTDKN3DU5F0443875  2015         toyota           prius  excellent
# 5176  1D7RV1GT0BS590812  2011            ram        1500 4x4  excellent
# 5177  2GCVKRECXJ1109515  2018      chevrolet  silverado 1500  excellent
#
#         cylinders    fuel  odometer title_status transmission   ac drive  \
# ...

# %%
Listings_Vehicle = pd.merge(Listings, Vehicles, on=['VIN'], how='inner')

# %%
Locations
# Out:
#               id                   region country state        lat        long
# 0     7308292096                 columbus      US    ia  42.200470  -91.784849
# 1     7315624604             jacksonville      US    tn  34.339300  -84.375800
# 2     7316066308            new york city      US    nj  40.322110  -74.073255
# 3     7316538404                 portland      US    sc  33.782700  -79.147300
# 4     7305627043                 lakeland      US    wi  45.836298  -87.040300
# ...          ...                      ...     ...   ...        ...         ...
# 5173  7309811406                    maine      US    wa  47.440591 -122.220413
# 5174  7314450544  spokane / coeur d'alene      US    va  37.565746  -77.478206
# 5175  7315259946               birmingham      US    wa  47.228000 -122.539600
# 5176  7315248956                rochester      US    wa  47.440591 -122.220413
# 5177  7310169898              south coast      US    wv  39.627322  -79.988846
#
# [5178 rows x 6 columns]

# %%
Locations = Locations.iloc[:,:-2]

# %%
Locations
# Out:
#               id                   region country state
# 0     7308292096                 columbus      US    ia
# 1     7315624604             jacksonville      US    tn
# 2     7316066308            new york city      US    nj
# 3     7316538404                 portland      US    sc
# 4     7305627043                 lakeland      US    wi
# ...          ...                      ...     ...   ...
# 5173  7309811406                    maine      US    wa
# 5174  7314450544  spokane / coeur d'alene      US    va
# 5175  7315259946               birmingham      US    wa
# 5176  7315248956                rochester      US    wa
# 5177  7310169898              south coast      US    wv
#
# [5178 rows x 4 columns]

# %%
Locations['country'].value_counts()
# Out:
# US    5173
# pa       1
# k        1
# il       1
# fl       1
# me       1
# Name: country, dtype: int64

# %%
Locations = Locations[Locations['country'] == 'US']

# %%
Locations
# Out:
#               id                   region country state
# 0     7308292096                 columbus      US    ia
# 1     7315624604             jacksonville      US    tn
# 2     7316066308            new york city      US    nj
# 3     7316538404                 portland      US    sc
# 4     7305627043                 lakeland      US    wi
# ...          ...                      ...     ...   ...
# 5173  7309811406                    maine      US    wa
# 5174  7314450544  spokane / coeur d'alene      US    va
# 5175  7315259946               birmingham      US    wa
# 5176  7315248956                rochester      US    wa
# 5177  7310169898              south coast      US    wv
#
# [5173 rows x 4 columns]

# %%
Locations['country'].value_counts()
# Out:
# US    5173
# Name: country, dtype: int64

# %%
Locations['region'].value_counts()
# Out:
# vermont                    106
# omaha / council bluffs      79
# minneapolis / st paul       73
# central NJ                  73
# nashville                   66
#                           ...
# eastern CO                   1
# yuba-sutter                  1
# cookeville                   1
# saginaw-midland-baycity      1
# elko                         1
# Name: region, Length: 335, dtype: int64

# %%
dataset = pd.merge(Listings_Vehicle, Locations, on=['id'], how='inner')

# %%
dataset
# Out:
#               id  price                VIN  year   manufacturer  \
# 0     7301603102  17995  1G6AG5RX3D0179091  2013       cadillac
# 1     7301683174   9995  1FAHP2E81FG150990  2015           ford
# 2     7301685395  24995  1N6BF0LYXHN802740  2017         nissan
# 3     7301698635  17000        H255B003251  1955      chevrolet
# 4     7301699921   6795  1FTPX14V66NB58277  2006           ford
# ...          ...    ...                ...   ...            ...
# 5172  7317070815  22995  WDAPF4CC7C9507524  2012  mercedes-benz
# 5173  7317074981  14900  JF2SJADC4FG514905  2015         subaru
# 5174  7317080335  14000  JTDKN3DU5F0443875  2015         toyota
# 5175  7317096069  11995  1D7RV1GT0BS590812  2011            ram
# 5176  7317096748  34000  2GCVKRECXJ1109515  2018      chevrolet
#
#                model  condition    cylinders    fuel  odometer title_status  \
# 0            ats awd  excellent  4 cylinders     gas     33444        clean
# ...

# %%
dataset['country'].value_counts()
# Out:
# US    5177
# Name: country, dtype: int64

# %%
dataset.isnull().sum()
# Out:
# id                 0
# price              0
# VIN                0
# year               0
# manufacturer       0
# model              1
# condition          1
# cylinders          1
# fuel               2
# odometer           0
# title_status       0
# transmission       0
# ac              4588
# drive              0
# size               0
# type               0
# paint_color        0
# region             0
# country            0
# state              0
# dtype: int64

# %%
dataset['ac'] = dataset['ac'].fillna(0)

# %%
dataset.isnull().sum()
# Out:
# id              0
# price           0
# VIN             0
# year            0
# manufacturer    0
# model           1
# condition       1
# cylinders       1
# fuel            2
# odometer        0
# title_status    0
# transmission    0
# ac              0
# drive           0
# size            0
# type            0
# paint_color     0
# region          0
# country         0
# state           0
# dtype: int64

# %%
dataset[['model', 'condition', 'cylinders', 'fuel']].value_counts()
# Out:
# model              condition  cylinders    fuel
# f-150              excellent  8 cylinders  gas     36
# silverado 1500     excellent  8 cylinders  gas     35
# 1500               excellent  8 cylinders  gas     34
# f-150              excellent  6 cylinders  gas     31
# silverado 1500     good       8 cylinders  gas     31
#                                                    ..
# explorer xlt 4x4   excellent  6 cylinders  gas      1
#                    good       6 cylinders  gas      1
# explorer xlt. 4wd  excellent  6 cylinders  gas      1
# exploror xlt       good       8 cylinders  gas      1
# z4 2.5i            excellent  6 cylinders  gas      1
# Length: 2964, dtype: int64

# %%
dataset['model'] = dataset['model'].fillna('f-150')

# %%
dataset['condition'] = dataset['condition'].fillna('excellent')

# %%
dataset['cylinders'] = dataset['cylinders'].fillna('8 cylinders')

# %%
dataset['fuel'] = dataset['fuel'].fillna('gas')

# %%
dataset.isnull().sum()
# Out:
# id              0
# price           0
# VIN             0
# year            0
# manufacturer    0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# title_status    0
# transmission    0
# ac              0
# drive           0
# size            0
# type            0
# paint_color     0
# region          0
# country         0
# state           0
# dtype: int64

# %%
dataset['price'] = dataset['price'].abs()

# %%
dataset = dataset[dataset['price'] > 500]

# %%
dataset
# Out:
#               id  price                VIN  year   manufacturer  \
# 0     7301603102  17995  1G6AG5RX3D0179091  2013       cadillac
# 1     7301683174   9995  1FAHP2E81FG150990  2015           ford
# 2     7301685395  24995  1N6BF0LYXHN802740  2017         nissan
# 3     7301698635  17000        H255B003251  1955      chevrolet
# 4     7301699921   6795  1FTPX14V66NB58277  2006           ford
# ...          ...    ...                ...   ...            ...
# 5172  7317070815  22995  WDAPF4CC7C9507524  2012  mercedes-benz
# 5173  7317074981  14900  JF2SJADC4FG514905  2015         subaru
# 5174  7317080335  14000  JTDKN3DU5F0443875  2015         toyota
# 5175  7317096069  11995  1D7RV1GT0BS590812  2011            ram
# 5176  7317096748  34000  2GCVKRECXJ1109515  2018      chevrolet
#
#                model  condition    cylinders    fuel  odometer title_status  \
# 0            ats awd  excellent  4 cylinders     gas     33444        clean
# ...

# %%
dataset['manufacturer'].value_counts().plot.bar(title = 'Manufacturers bar graph',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturers bar graph'}>

# %%
dataset['manufacturer'].value_counts()
# Out:
# ford             905
# chevrolet        694
# toyota           472
# honda            355
# nissan           280
# jeep             225
# ram              209
# gmc              202
# subaru           163
# dodge            159
# bmw              138
# volkswagen       131
# hyundai          123
# mercedes-benz    123
# chrysler         106
# kia              102
# lexus             99
# cadillac          81
# audi              73
# buick             66
# mazda             64
# volvo             45
# acura             44
# pontiac           39
# infiniti          34
# lincoln           34
# mini              34
# mitsubishi        32
# porsche           28
# mercury           21
# rover             20
# saturn            18
# jaguar            15
# fiat               8
# alfa-romeo         3
# tesla              3
# ferrari            2
# datsun             1
# aston-martin       1
# Name: manufacturer, dtype: int64

# %%
ford_dataset = dataset[dataset['manufacturer'] == 'ford']

# %%
ford_dataset['model'].value_counts()
# Out:
# f-150                   108
# escape                   47
# mustang                  28
# explorer                 23
# fusion                   19
#                        ...
# e-250 wheelchair van      1
# f-450 sd                  1
# fusion se 4dr sedan       1
# f-150 lariat 4x4          1
# explorer eddie bauer      1
# Name: model, Length: 328, dtype: int64

# %%
ford_dataset['region'].value_counts()
# Out:
# nashville               24
# detroit metro           17
# st louis, MO            15
# madison                 15
# stockton                14
#                         ..
# appleton-oshkosh-FDL     1
# winston-salem            1
# milwaukee                1
# quad cities, IA/IL       1
# cumberland valley        1
# Name: region, Length: 230, dtype: int64

# %%
ford_dataset['state'].value_counts()
# Out:
# ca    89
# fl    71
# tx    60
# ny    55
# oh    37
# co    36
# az    35
# or    33
# pa    32
# mi    31
# ia    25
# nj    25
# ma    24
# mn    23
# ks    23
# va    23
# wi    20
# il    19
# nc    19
# wa    19
# tn    18
# id    18
# ok    15
# ga    14
# vt    11
# mt    11
# sc    11
# in    10
# al     9
# mo     9
# ky     9
# ak     7
# nh     7
# me     7
# hi     6
# nv     5
# ct     5
# nm     5
# ut     5
# nd     5
# ne     4
# md     3
# wy     2
# sd     2
# de     2
# dc     2
# la     1
# ri     1
# ar     1
# ms     1
# Name: state, dtype: int64

# %%
ford_dataset['type'].value_counts().plot.bar(figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %%
chevrolet_dataset = dataset[dataset['manufacturer'] == 'chevrolet']

# %%
chevrolet_dataset['model'].value_counts()
# Out:
# silverado 1500           92
# equinox                  36
# silverado 2500hd         28
# tahoe                    25
# cruze                    25
#                          ..
# avalanche z71             1
# colorado extended cab     1
# ex-cab z-71 4x4           1
# malibu eco                1
# astro cargo               1
# Name: model, Length: 219, dtype: int64

# %%
chevrolet_dataset['region'].value_counts()
# Out:
# cedar rapids              14
# vermont                   14
# rochester                 13
# green bay                 12
# omaha / council bluffs    12
#                           ..
# winchester                 1
# duluth / superior          1
# cumberland valley          1
# southern illinois          1
# morgantown                 1
# Name: region, Length: 214, dtype: int64

# %%
chevrolet_dataset['state'].value_counts()
# Out:
# ca    80
# fl    55
# tx    40
# ny    35
# mi    33
# or    31
# mn    28
# pa    23
# wi    23
# oh    22
# il    22
# nj    20
# az    19
# va    18
# co    18
# ia    18
# nc    16
# tn    15
# id    13
# ma    13
# ks    12
# ok    11
# in    10
# wa    10
# vt     9
# hi     8
# mo     8
# mt     8
# nm     7
# sc     7
# al     6
# ky     6
# ga     6
# me     5
# sd     5
# ak     5
# ne     4
# nv     4
# nh     4
# la     3
# ri     2
# wy     2
# dc     2
# ut     2
# de     2
# ms     1
# ct     1
# ar     1
# wv     1
# Name: state, dtype: int64

# %%
chevrolet_dataset['type'].value_counts().plot.bar(figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %%
honda_dataset = dataset[dataset['manufacturer'] == 'honda']

# %%
honda_dataset['model'].value_counts()
# Out:
# cr-v                   37
# civic                  29
# accord                 28
# odyssey                26
# pilot                  17
#                        ..
# pilot touring w/nav     1
# odysee ex-l             1
# odyssey ex              1
# civic cpe               1
# accord sedan lx         1
# Name: model, Length: 106, dtype: int64

# %%
honda_dataset['region'].value_counts()
# Out:
# central NJ            12
# atlanta                8
# vermont                8
# sarasota-bradenton     7
# fresno / madera        6
#                       ..
# grand rapids           1
# bemidji                1
# jackson                1
# bloomington-normal     1
# boulder                1
# Name: region, Length: 169, dtype: int64

# %%
honda_dataset['state'].value_counts()
# Out:
# fl    38
# ca    23
# ny    20
# ia    17
# or    16
# mi    16
# nj    15
# nc    15
# oh    13
# wi    12
# pa    11
# in    10
# tx    10
# va    10
# vt     9
# mn     8
# sc     8
# mt     8
# co     8
# tn     8
# ks     7
# az     7
# il     6
# id     6
# nm     5
# ak     4
# ky     4
# al     4
# ut     4
# wa     4
# ct     3
# hi     3
# ar     2
# ma     2
# sd     2
# dc     2
# ms     2
# md     2
# ne     1
# me     1
# wy     1
# nh     1
# de     1
# nd     1
# ri     1
# ga     1
# wv     1
# nv     1
# ok     1
# Name: state, dtype: int64

# %%
honda_dataset['type'].value_counts().plot.bar(figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %%
toyota_dataset = dataset[dataset['manufacturer'] == 'toyota']

# %%
toyota_dataset['model'].value_counts()
# Out:
# corolla                    34
# prius                      34
# camry                      33
# tundra                     30
# tacoma                     28
#                            ..
# tundra crewmax sr5 4x4      1
# tacoma trd                  1
# prius iii                   1
# pilot exl                   1
# tacoma 4x4 trd off road     1
# Name: model, Length: 133, dtype: int64

# %%
toyota_dataset['region'].value_counts()
# Out:
# eugene             12
# kansas city, MO    11
# vermont            10
# seattle-tacoma     10
# san diego          10
#                    ..
# pueblo              1
# augusta             1
# oregon coast        1
# winchester          1
# outer banks         1
# Name: region, Length: 169, dtype: int64

# %%
honda_dataset['state'].value_counts()
# Out:
# fl    38
# ca    23
# ny    20
# ia    17
# or    16
# mi    16
# nj    15
# nc    15
# oh    13
# wi    12
# pa    11
# in    10
# tx    10
# va    10
# vt     9
# mn     8
# sc     8
# mt     8
# co     8
# tn     8
# ks     7
# az     7
# il     6
# id     6
# nm     5
# ak     4
# ky     4
# al     4
# ut     4
# wa     4
# ct     3
# hi     3
# ar     2
# ma     2
# sd     2
# dc     2
# ms     2
# md     2
# ne     1
# me     1
# wy     1
# nh     1
# de     1
# nd     1
# ri     1
# ga     1
# wv     1
# nv     1
# ok     1
# Name: state, dtype: int64

# %%
toyota_dataset['type'].value_counts().plot.bar(figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %%
dataset['paint_color'].value_counts()
# Out:
# white     1234
# black      936
# silver     789
# grey       674
# blue       540
# red        468
# brown      144
# green      143
# custom     140
# yellow      41
# orange      33
# purple      10
# Name: paint_color, dtype: int64

# %%
mixed = dataset[dataset['manufacturer'].isin(['ford', 'chevrolet', 'toyota', 'honda'])]

# %%
mixed
# Out:
#               id  price                VIN  year manufacturer  \
# 1     7301683174   9995  1FAHP2E81FG150990  2015         ford
# 3     7301698635  17000        H255B003251  1955    chevrolet
# 4     7301699921   6795  1FTPX14V66NB58277  2006         ford
# 5     7301705577  11995  3GNFK12338G146036  2008    chevrolet
# 6     7301707377  10000        0A28NXXXXXX  1970         ford
# ...          ...    ...                ...   ...          ...
# 5164  7317026431  29999  3TMLU4EN6FM187358  2015       toyota
# 5165  7317028736  17950  1FDXE4FL2CDA32031  2012         ford
# 5169  7317058919  19495  5TELU42N28Z566500  2008       toyota
# 5174  7317080335  14000  JTDKN3DU5F0443875  2015       toyota
# 5176  7317096748  34000  2GCVKRECXJ1109515  2018    chevrolet
#
#                         model  condition    cylinders    fuel  odometer  \
# 1                  taurus sel  excellent  6 cylinders     gas    104112
# 3                      pickup       good  6 cylinders     gas     99999
# ...

# %%
mixed['model'].value_counts()
# Out:
# f-150                      109
# silverado 1500              92
# escape                      47
# cr-v                        37
# equinox                     36
#                           ...
# f750                         1
# edge titanium                1
# f450 sd xl                   1
# accord sdn lx-p              1
# tacoma 4x4 trd off road      1
# Name: model, Length: 783, dtype: int64

# %%
mixed['state'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda'}>

# %%
mixed['region'].value_counts()
# Out:
# vermont                   42
# central NJ                41
# nashville                 38
# omaha / council bluffs    37
# kansas city, MO           36
#                           ..
# provo / orem               1
# hilton head                1
# gulfport / biloxi          1
# st augustine               1
# morgantown                 1
# Name: region, Length: 295, dtype: int64

# %%
mixed[mixed['state'].isin(['ca','fl'])]['region'].value_counts()
# Out:
# omaha / council bluffs     12
# nashville                  11
# vermont                     8
# kansas city, MO             7
# greenville / upstate        7
#                            ..
# greensboro                  1
# corpus christi              1
# plattsburgh-adirondacks     1
# hudson valley               1
# cumberland valley           1
# Name: region, Length: 179, dtype: int64

# %%
mixed['type'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda',figsize=(15, 15))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda'}>

# %%
mixed['ac'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda'}>

# %%
mixed['transmission'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda'}>

# %%
mixed['cylinders'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda'}>

# %%
mixed[mixed['type'] != 'truck']['fuel'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda'}>

# %%
mixed[mixed['type'] != 'truck']['drive'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda'}>

# %%
mixed[mixed['type'] != 'truck']['paint_color'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda'}>

# %%
mixed[mixed['type'] != 'truck']['size'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda'}>

# %%
mixed[mixed['model'] == 'f-150']['manufacturer'].value_counts()
# Out:
# ford         108
# chevrolet      1
# Name: manufacturer, dtype: int64

# %%
dataset['price'].describe()
# Out:
# count      5152.000000
# mean      14957.066770
# std       11704.794624
# min         600.000000
# 25%        6995.000000
# 50%       11500.000000
# 75%       18995.000000
# max      120000.000000
# Name: price, dtype: float64

# %%
mixed['price'].describe()
# Out:
# count     2426.000000
# mean     15353.001237
# std      11903.815080
# min        600.000000
# 25%       6995.000000
# 50%      11900.000000
# 75%      19945.750000
# max      89000.000000
# Name: price, dtype: float64

# %%
mixed[mixed['state'].isin(['ca','fl'])]['price'].describe()
# Out:
# count      441.000000
# mean     15627.503401
# std      10204.168232
# min       1000.000000
# 25%       7790.000000
# 50%      12999.000000
# 75%      20895.000000
# max      49995.000000
# Name: price, dtype: float64

# %%
dataset
# Out:
#               id  price                VIN  year   manufacturer  \
# 0     7301603102  17995  1G6AG5RX3D0179091  2013       cadillac
# 1     7301683174   9995  1FAHP2E81FG150990  2015           ford
# 2     7301685395  24995  1N6BF0LYXHN802740  2017         nissan
# 3     7301698635  17000        H255B003251  1955      chevrolet
# 4     7301699921   6795  1FTPX14V66NB58277  2006           ford
# ...          ...    ...                ...   ...            ...
# 5172  7317070815  22995  WDAPF4CC7C9507524  2012  mercedes-benz
# 5173  7317074981  14900  JF2SJADC4FG514905  2015         subaru
# 5174  7317080335  14000  JTDKN3DU5F0443875  2015         toyota
# 5175  7317096069  11995  1D7RV1GT0BS590812  2011            ram
# 5176  7317096748  34000  2GCVKRECXJ1109515  2018      chevrolet
#
#                model  condition    cylinders    fuel  odometer title_status  \
# 0            ats awd  excellent  4 cylinders     gas     33444        clean
# ...

# %%
dataset['paint_color'].value_counts().plot.bar(title= 'Color',figsize=(10, 8))
# Out:
# <AxesSubplot:title={'center':'Color'}>

# %%
dataset['fuel'].value_counts().plot.bar(title= 'Fuel Type',figsize=(10, 10))
# Out:
# <AxesSubplot:title={'center':'Fuel Type'}>

# %%
dataset['ac'].value_counts().plot.bar(title= 'Air Condition Type',figsize=(10, 10))
# Out:
# <AxesSubplot:title={'center':'Air Condition Type'}>

# %%
dataset['drive'].value_counts().plot.bar(title= 'Drive Type',figsize=(10, 10))
# Out:
# <AxesSubplot:title={'center':'Drive Type'}>

# %%
dataset[['fuel', 'ac', 'drive', 'paint_color']].value_counts().plot.bar(title= 'Fuel Type',figsize=(20, 10))
# Out:
# <AxesSubplot:title={'center':'Fuel Type'}, xlabel='fuel,ac,drive,paint_color'>

# %%
dataset['state'].value_counts()
# Out:
# ca    541
# fl    403
# ny    287
# tx    266
# mi    202
# or    199
# pa    172
# ia    171
# oh    169
# wi    165
# co    159
# mn    145
# nj    143
# nc    141
# il    137
# va    133
# az    129
# tn    117
# ma    114
# vt    105
# id    105
# ks    104
# in     77
# sc     76
# ok     69
# wa     68
# mt     58
# ga     54
# ak     52
# ky     50
# al     47
# nm     47
# mo     46
# hi     35
# nh     34
# dc     34
# me     33
# nv     32
# ct     31
# ri     31
# ne     28
# sd     25
# ut     23
# la     20
# wy     14
# md     14
# ms     12
# nd     11
# ar     11
# de      8
# wv      5
# Name: state, dtype: int64

# %%
mixed[mixed['state'].isin(['ca','fl'])]['type'].value_counts().plot.bar(title= 'Manufacturer is Ford, chevrolet, toyota, and honda and State is CA, and FL',figsize=(15, 10))
# Out:
# <AxesSubplot:title={'center':'Manufacturer is Ford, chevrolet, toyota, and honda and State is CA, and FL'}>

# %%
dataset
# Out:
#               id  price                VIN  year   manufacturer  \
# 0     7301603102  17995  1G6AG5RX3D0179091  2013       cadillac
# 1     7301683174   9995  1FAHP2E81FG150990  2015           ford
# 2     7301685395  24995  1N6BF0LYXHN802740  2017         nissan
# 3     7301698635  17000        H255B003251  1955      chevrolet
# 4     7301699921   6795  1FTPX14V66NB58277  2006           ford
# ...          ...    ...                ...   ...            ...
# 5172  7317070815  22995  WDAPF4CC7C9507524  2012  mercedes-benz
# 5173  7317074981  14900  JF2SJADC4FG514905  2015         subaru
# 5174  7317080335  14000  JTDKN3DU5F0443875  2015         toyota
# 5175  7317096069  11995  1D7RV1GT0BS590812  2011            ram
# 5176  7317096748  34000  2GCVKRECXJ1109515  2018      chevrolet
#
#                model  condition    cylinders    fuel  odometer title_status  \
# 0            ats awd  excellent  4 cylinders     gas     33444        clean
# ...

# %%
df = dataset.drop(['id', 'VIN', 'year', 'region', 'country'], axis=1)

# %%
from sklearn.preprocessing import OrdinalEncoder # For handling categorical values.
ord_enc = OrdinalEncoder()
df["manufacturer"] = ord_enc.fit_transform(df[["manufacturer"]])
df["model"] = ord_enc.fit_transform(df[["model"]])
df["condition"] = ord_enc.fit_transform(df[["condition"]])
df["cylinders"] = ord_enc.fit_transform(df[["cylinders"]])
df["fuel"] = ord_enc.fit_transform(df[["fuel"]])
df["title_status"] = ord_enc.fit_transform(df[["title_status"]])
df["transmission"] = ord_enc.fit_transform(df[["transmission"]])
df["drive"] = ord_enc.fit_transform(df[["drive"]])
df["size"] = ord_enc.fit_transform(df[["size"]])
df["type"] = ord_enc.fit_transform(df[["type"]])
df["paint_color"] = ord_enc.fit_transform(df[["paint_color"]])
df["state"] = ord_enc.fit_transform(df[["state"]])

# %%
X = df.drop(['price'], axis=1)

# %%
y = df['price']

# %%
X
# Out:
#       manufacturer   model  condition  cylinders  fuel  odometer  \
# 0              6.0   263.0        0.0        3.0   2.0     33444
# 1             13.0  1746.0        0.0        5.0   2.0    104112
# 2             28.0  1310.0        2.0        5.0   2.0     56512
# 3              7.0  1365.0        2.0        5.0   2.0     99999
# 4             13.0   795.0        2.0        6.0   2.0    124500
# ...            ...     ...        ...        ...   ...       ...
# 5172          24.0  1678.0        0.0        5.0   0.0    186000
# 5173          34.0   934.0        0.0        3.0   2.0     83000
# 5174          36.0  1381.0        0.0        3.0   3.0     56500
# 5175          31.0     3.0        0.0        6.0   2.0    206381
# 5176           7.0  1596.0        0.0        6.0   2.0     28000
#
#       title_status  transmission   ac  drive  size  type  paint_color  state
# 0              0.0           0.0  0.0    0.0   2.0   9.0          0.0    5.0
# ...

# %%
y
# Out:
# 0       17995
# 1        9995
# 2       24995
# 3       17000
# 4        6795
#         ...
# 5172    22995
# 5173    14900
# 5174    14000
# 5175    11995
# 5176    34000
# Name: price, Length: 5152, dtype: int64

# %%
# Scaler is used to scale the data so that we can improve our model training.
from sklearn.preprocessing import StandardScaler # To Scale the data.
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split # For splitting data into train and test data.
X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.3, random_state=42)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import linear_model
from sklearn import svm
from sklearn import tree
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %%
model_1 = RandomForestRegressor(n_estimators = 400,min_samples_split = 4,min_samples_leaf = 1,max_features= 'sqrt',max_depth =None,bootstrap= False)
model_1.fit(X_train, y_train)
predict_1 = model_1.predict(X_test)
model_2= linear_model.Ridge()
model_2.fit(X_train, y_train)
predict_2 = model_2.predict(X_test)
model_3 =KNeighborsRegressor(10,weights='uniform')
model_3.fit(X_train, y_train)
predict_3 = model_3.predict(X_test)
model_4 = linear_model.BayesianRidge()
model_4.fit(X_train, y_train)
predict_4 = model_4.predict(X_test)
model_5 = tree.DecisionTreeRegressor(max_depth=1)
model_5.fit(X_train, y_train)
predict_5 = model_5.predict(X_test)
model_6= svm.SVR(C=1.0, epsilon=0.2)
model_6.fit(X_train, y_train)
predict_6 = model_6.predict(X_test)
model_7 = xgb.XGBRegressor()
model_7.fit(X_train, y_train)
predict_7 = model_7.predict(X_test)

# %%
print(model_1.score(X_test, y_test))
print(model_2.score(X_test, y_test))
print(model_3.score(X_test, y_test))
print(model_4.score(X_test, y_test))
print(model_5.score(X_test, y_test))
print(model_6.score(X_test, y_test))
print(model_7.score(X_test, y_test))
# Out:
# 0.6558347403082112
# 0.4121056716170326
# 0.4639888360350013
# 0.41084458816370484
# 0.19867449740788545
# -0.07618720705413051
# 0.6697751123001183
